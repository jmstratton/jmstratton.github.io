# %%
#dependencies
import random
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import json
import pprint
from citipy import citipy

# %%
#api keys
from config import WKey
from config import GKey

#style settings for plots
plt.style.use("seaborn")

# %%
#Generating random latitudes and longitudes
lat = np.random.uniform(low=-90, high=90, size=2000)
lng = np.random.uniform(low=-180, high=180, size=2000)

#Creating coordinate pairs
coordinates = []
for x in range(0,len(lat)):
    coordinates.append((lat[x], lng[x]))

# %%
#Finding the cities nearest to the coordinates
cities = []
for coordinate_pair in coordinates:
    lat, lon = coordinate_pair
    cities.append(citipy.nearest_city(lat, lon))

# %%
#Creating DataFrame
cities_df = pd.DataFrame(cities)
cities_df["City Name"] = ""
cities_df["Country Code"] = ""

for index, row in cities_df.iterrows():
    row["City Name"] = cities_df.iloc[index,0].city_name
    row["Country Code"] = cities_df.iloc[index,0].country_code
    
cities_df.head()
# Out:
#                                                    0  City Name Country Code
# 0  <citipy.citipy.City object at 0x0000023CD302C208>  upernavik           gl
# 1  <citipy.citipy.City object at 0x0000023CD3971A90>     atuona           pf
# 2  <citipy.citipy.City object at 0x0000023CD2AE9B38>    iqaluit           ca
# 3  <citipy.citipy.City object at 0x0000023CD40C4550>       gizo           sb
# 4  <citipy.citipy.City object at 0x0000023CD425E518>     bethel           us

# %%
#Dropping duplicate cities
cities_df.drop_duplicates(['City Name', 'Country Code'], inplace=True)
cities_df.reset_index(inplace=True)
cities_df.head()
# Out:
#    index                                                  0  City Name  \
# 0      0  <citipy.citipy.City object at 0x0000023CD302C208>  upernavik
# 1      1  <citipy.citipy.City object at 0x0000023CD3971A90>     atuona
# 2      2  <citipy.citipy.City object at 0x0000023CD2AE9B38>    iqaluit
# 3      3  <citipy.citipy.City object at 0x0000023CD40C4550>       gizo
# 4      4  <citipy.citipy.City object at 0x0000023CD425E518>     bethel
#
#   Country Code
# 0           gl
# 1           pf
# 2           ca
# 3           sb
# 4           us

# %%
# Deleting unnecessary columns
del cities_df[0]
del cities_df['index']

cities_df.head()
# Out:
#    City Name Country Code
# 0  upernavik           gl
# 1     atuona           pf
# 2    iqaluit           ca
# 3       gizo           sb
# 4     bethel           us

# %%
# Adding columns for values
cities_df['Latitude'] = ""
cities_df['Longitude'] = ""
cities_df['Temperature (F)'] = ""
cities_df['Humidity (%)'] = ""
cities_df['Cloudiness (%)'] = ""
cities_df['Wind Speed (mph)'] = ""

cities_df.head()
# Out:
#    City Name Country Code Latitude Longitude Temperature (F) Humidity (%)  \
# 0  upernavik           gl
# 1     atuona           pf
# 2    iqaluit           ca
# 3       gizo           sb
# 4     bethel           us
#
#   Cloudiness (%) Wind Speed (mph)
# 0
# 1
# 2
# 3
# 4

# %%
# Accessing data
print("Beginning Data Retrieval")
print("---------------------------------")

for index, row in cities_df.iterrows():
    # Building target url
    url = "http://api.openweathermap.org/data/2.5/weather?q=%s,%s&units=imperial&appid=%s" % (row['City Name'], row['Country Code'], WKey)
   
    # Printing to ensure loop is correct
    print("Now retrieving City #" + str(index) + ": " + row['City Name'] + ", " + row['Country Code'])
    print(url)
    
    # Running request
    weather_data = requests.get(url).json()
    
    try:
        # Appending latitude and longitude to correct location
        row['Latitude'] = weather_data['coord']['lat']
        row['Longitude'] = weather_data['coord']['lon']
    
        # Appending temperature to correct location
        row['Temperature (F)'] = weather_data['main']['temp']
    
        # Appending humidity to correct location
        row['Humidity (%)'] = weather_data['main']['humidity']
    
        # Appending cloudiness to correct location
        row['Cloudiness (%)'] = weather_data['clouds']['all']
    
        # Appending wind speed to correct location
        row['Wind Speed (mph)'] = weather_data['wind']['speed']
    except:
        print("Error with city data. Skipping")
        continue

print("---------------------------------")
print("Data Retrieval Complete")
print("---------------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------------
# Now retrieving City #0: upernavik, gl
# http://api.openweathermap.org/data/2.5/weather?q=upernavik,gl&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #1: atuona, pf
# http://api.openweathermap.org/data/2.5/weather?q=atuona,pf&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #2: iqaluit, ca
# http://api.openweathermap.org/data/2.5/weather?q=iqaluit,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #3: gizo, sb
# http://api.openweathermap.org/data/2.5/weather?q=gizo,sb&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #4: bethel, us
# http://api.openweathermap.org/data/2.5/weather?q=bethel,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #5: ola, ru
# http://api.openweathermap.org/data/2.5/weather?q=ola,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #6: aginskoye, ru
# http://api.openweathermap.org/data/2.5/weather?q=aginskoye,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #7: carnarvon, au
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #8: beyneu, kz
# http://api.openweathermap.org/data/2.5/weather?q=beyneu,kz&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #9: chokurdakh, ru
# http://api.openweathermap.org/data/2.5/weather?q=chokurdakh,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #10: albany, au
# http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #11: qaanaaq, gl
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq,gl&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #12: vaini, to
# http://api.openweathermap.org/data/2.5/weather?q=vaini,to&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #13: punta arenas, cl
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #14: vaitupu, wf
# http://api.openweathermap.org/data/2.5/weather?q=vaitupu,wf&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #15: castro, cl
# http://api.openweathermap.org/data/2.5/weather?q=castro,cl&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #16: mackay, au
# http://api.openweathermap.org/data/2.5/weather?q=mackay,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #17: taolanaro, mg
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro,mg&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #18: ushuaia, ar
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #19: puerto ayora, ec
# http://api.openweathermap.org/data/2.5/weather?q=puerto ayora,ec&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #20: lata, sb
# http://api.openweathermap.org/data/2.5/weather?q=lata,sb&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #21: hobyo, so
# http://api.openweathermap.org/data/2.5/weather?q=hobyo,so&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #22: liverpool, ca
# http://api.openweathermap.org/data/2.5/weather?q=liverpool,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #23: norman wells, ca
# http://api.openweathermap.org/data/2.5/weather?q=norman wells,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #24: umzimvubu, za
# http://api.openweathermap.org/data/2.5/weather?q=umzimvubu,za&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #25: victor harbor, au
# http://api.openweathermap.org/data/2.5/weather?q=victor harbor,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #26: katobu, id
# http://api.openweathermap.org/data/2.5/weather?q=katobu,id&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #27: butaritari, ki
# http://api.openweathermap.org/data/2.5/weather?q=butaritari,ki&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #28: east london, za
# http://api.openweathermap.org/data/2.5/weather?q=east london,za&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #29: saldanha, za
# http://api.openweathermap.org/data/2.5/weather?q=saldanha,za&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #30: halalo, wf
# http://api.openweathermap.org/data/2.5/weather?q=halalo,wf&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #31: illoqqortoormiut, gl
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut,gl&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #32: thompson, ca
# http://api.openweathermap.org/data/2.5/weather?q=thompson,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #33: badulla, lk
# http://api.openweathermap.org/data/2.5/weather?q=badulla,lk&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #34: rabo de peixe, pt
# http://api.openweathermap.org/data/2.5/weather?q=rabo de peixe,pt&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #35: marti, cu
# http://api.openweathermap.org/data/2.5/weather?q=marti,cu&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #36: cabo san lucas, mx
# http://api.openweathermap.org/data/2.5/weather?q=cabo san lucas,mx&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #37: rikitea, pf
# http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #38: dikson, ru
# http://api.openweathermap.org/data/2.5/weather?q=dikson,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #39: cotonou, bj
# http://api.openweathermap.org/data/2.5/weather?q=cotonou,bj&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #40: mataura, pf
# http://api.openweathermap.org/data/2.5/weather?q=mataura,pf&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #41: bredasdorp, za
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #42: yining, cn
# http://api.openweathermap.org/data/2.5/weather?q=yining,cn&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #43: luderitz, na
# http://api.openweathermap.org/data/2.5/weather?q=luderitz,na&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #44: mys shmidta, ru
# http://api.openweathermap.org/data/2.5/weather?q=mys shmidta,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #45: richards bay, za
# http://api.openweathermap.org/data/2.5/weather?q=richards bay,za&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #46: adjumani, ug
# http://api.openweathermap.org/data/2.5/weather?q=adjumani,ug&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #47: tiksi, ru
# http://api.openweathermap.org/data/2.5/weather?q=tiksi,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #48: guiratinga, br
# http://api.openweathermap.org/data/2.5/weather?q=guiratinga,br&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #49: colares, pt
# http://api.openweathermap.org/data/2.5/weather?q=colares,pt&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #50: busselton, au
# http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #51: salinas, ec
# http://api.openweathermap.org/data/2.5/weather?q=salinas,ec&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #52: cape town, za
# http://api.openweathermap.org/data/2.5/weather?q=cape town,za&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #53: warqla, dz
# http://api.openweathermap.org/data/2.5/weather?q=warqla,dz&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #54: marcona, pe
# http://api.openweathermap.org/data/2.5/weather?q=marcona,pe&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #55: dharchula, in
# http://api.openweathermap.org/data/2.5/weather?q=dharchula,in&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #56: cidreira, br
# http://api.openweathermap.org/data/2.5/weather?q=cidreira,br&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #57: hami, cn
# http://api.openweathermap.org/data/2.5/weather?q=hami,cn&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #58: ugoofaaru, mv
# http://api.openweathermap.org/data/2.5/weather?q=ugoofaaru,mv&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #59: portland, au
# http://api.openweathermap.org/data/2.5/weather?q=portland,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #60: ust-kamchatsk, ru
# http://api.openweathermap.org/data/2.5/weather?q=ust-kamchatsk,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #61: boma, cd
# http://api.openweathermap.org/data/2.5/weather?q=boma,cd&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #62: sunrise manor, us
# http://api.openweathermap.org/data/2.5/weather?q=sunrise manor,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #63: mrirt, ma
# http://api.openweathermap.org/data/2.5/weather?q=mrirt,ma&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #64: kamenskoye, ru
# http://api.openweathermap.org/data/2.5/weather?q=kamenskoye,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #65: norsup, vu
# http://api.openweathermap.org/data/2.5/weather?q=norsup,vu&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #66: bluff, nz
# http://api.openweathermap.org/data/2.5/weather?q=bluff,nz&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #67: campolongo maggiore, it
# http://api.openweathermap.org/data/2.5/weather?q=campolongo maggiore,it&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #68: pirai do sul, br
# http://api.openweathermap.org/data/2.5/weather?q=pirai do sul,br&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #69: paamiut, gl
# http://api.openweathermap.org/data/2.5/weather?q=paamiut,gl&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #70: fairbanks, us
# http://api.openweathermap.org/data/2.5/weather?q=fairbanks,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #71: lebu, cl
# http://api.openweathermap.org/data/2.5/weather?q=lebu,cl&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #72: port alfred, za
# http://api.openweathermap.org/data/2.5/weather?q=port alfred,za&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #73: hilo, us
# http://api.openweathermap.org/data/2.5/weather?q=hilo,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #74: tignere, cm
# http://api.openweathermap.org/data/2.5/weather?q=tignere,cm&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #75: cockburn harbour, tc
# http://api.openweathermap.org/data/2.5/weather?q=cockburn harbour,tc&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #76: half moon bay, us
# http://api.openweathermap.org/data/2.5/weather?q=half moon bay,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #77: muzhi, ru
# http://api.openweathermap.org/data/2.5/weather?q=muzhi,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #78: dunedin, nz
# http://api.openweathermap.org/data/2.5/weather?q=dunedin,nz&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #79: zhigansk, ru
# http://api.openweathermap.org/data/2.5/weather?q=zhigansk,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #80: port elizabeth, za
# http://api.openweathermap.org/data/2.5/weather?q=port elizabeth,za&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #81: amderma, ru
# http://api.openweathermap.org/data/2.5/weather?q=amderma,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #82: nishihara, jp
# http://api.openweathermap.org/data/2.5/weather?q=nishihara,jp&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #83: hobart, au
# http://api.openweathermap.org/data/2.5/weather?q=hobart,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #84: scicli, it
# http://api.openweathermap.org/data/2.5/weather?q=scicli,it&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #85: bengkulu, id
# http://api.openweathermap.org/data/2.5/weather?q=bengkulu,id&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #86: provideniya, ru
# http://api.openweathermap.org/data/2.5/weather?q=provideniya,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #87: lazaro cardenas, mx
# http://api.openweathermap.org/data/2.5/weather?q=lazaro cardenas,mx&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #88: avarua, ck
# http://api.openweathermap.org/data/2.5/weather?q=avarua,ck&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #89: meulaboh, id
# http://api.openweathermap.org/data/2.5/weather?q=meulaboh,id&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #90: birjand, ir
# http://api.openweathermap.org/data/2.5/weather?q=birjand,ir&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #91: moerai, pf
# http://api.openweathermap.org/data/2.5/weather?q=moerai,pf&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #92: tabialan, ph
# http://api.openweathermap.org/data/2.5/weather?q=tabialan,ph&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #93: sheridan, us
# http://api.openweathermap.org/data/2.5/weather?q=sheridan,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #94: anuradhapura, lk
# http://api.openweathermap.org/data/2.5/weather?q=anuradhapura,lk&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #95: faanui, pf
# http://api.openweathermap.org/data/2.5/weather?q=faanui,pf&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #96: torbay, ca
# http://api.openweathermap.org/data/2.5/weather?q=torbay,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #97: khatanga, ru
# http://api.openweathermap.org/data/2.5/weather?q=khatanga,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #98: san patricio, mx
# http://api.openweathermap.org/data/2.5/weather?q=san patricio,mx&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #99: salihorsk, by
# http://api.openweathermap.org/data/2.5/weather?q=salihorsk,by&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #100: saint-philippe, re
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe,re&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #101: teseney, er
# http://api.openweathermap.org/data/2.5/weather?q=teseney,er&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #102: belyy yar, ru
# http://api.openweathermap.org/data/2.5/weather?q=belyy yar,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #103: tarudant, ma
# http://api.openweathermap.org/data/2.5/weather?q=tarudant,ma&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #104: rio gallegos, ar
# http://api.openweathermap.org/data/2.5/weather?q=rio gallegos,ar&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #105: sao filipe, cv
# http://api.openweathermap.org/data/2.5/weather?q=sao filipe,cv&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #106: shimoda, jp
# http://api.openweathermap.org/data/2.5/weather?q=shimoda,jp&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #107: vestmannaeyjar, is
# http://api.openweathermap.org/data/2.5/weather?q=vestmannaeyjar,is&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #108: bandipur, in
# http://api.openweathermap.org/data/2.5/weather?q=bandipur,in&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #109: tuktoyaktuk, ca
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #110: sabang, id
# http://api.openweathermap.org/data/2.5/weather?q=sabang,id&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #111: codrington, ag
# http://api.openweathermap.org/data/2.5/weather?q=codrington,ag&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #112: labuhan, id
# http://api.openweathermap.org/data/2.5/weather?q=labuhan,id&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #113: vung tau, vn
# http://api.openweathermap.org/data/2.5/weather?q=vung tau,vn&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #114: new norfolk, au
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #115: zumarraga, es
# http://api.openweathermap.org/data/2.5/weather?q=zumarraga,es&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #116: narsaq, gl
# http://api.openweathermap.org/data/2.5/weather?q=narsaq,gl&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #117: nantucket, us
# http://api.openweathermap.org/data/2.5/weather?q=nantucket,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #118: lompoc, us
# http://api.openweathermap.org/data/2.5/weather?q=lompoc,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #119: copiapo, cl
# http://api.openweathermap.org/data/2.5/weather?q=copiapo,cl&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #120: kodinsk, ru
# http://api.openweathermap.org/data/2.5/weather?q=kodinsk,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #121: tazovskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=tazovskiy,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #122: mitu, co
# http://api.openweathermap.org/data/2.5/weather?q=mitu,co&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #123: zorritos, pe
# http://api.openweathermap.org/data/2.5/weather?q=zorritos,pe&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #124: pacasmayo, pe
# http://api.openweathermap.org/data/2.5/weather?q=pacasmayo,pe&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #125: mar del plata, ar
# http://api.openweathermap.org/data/2.5/weather?q=mar del plata,ar&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #126: mweka, cd
# http://api.openweathermap.org/data/2.5/weather?q=mweka,cd&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #127: clyde river, ca
# http://api.openweathermap.org/data/2.5/weather?q=clyde river,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #128: iquitos, pe
# http://api.openweathermap.org/data/2.5/weather?q=iquitos,pe&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #129: yellowknife, ca
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #130: zawiercie, pl
# http://api.openweathermap.org/data/2.5/weather?q=zawiercie,pl&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #131: dianopolis, br
# http://api.openweathermap.org/data/2.5/weather?q=dianopolis,br&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #132: krapivinskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=krapivinskiy,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #133: lakes entrance, au
# http://api.openweathermap.org/data/2.5/weather?q=lakes entrance,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #134: salalah, om
# http://api.openweathermap.org/data/2.5/weather?q=salalah,om&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #135: tuatapere, nz
# http://api.openweathermap.org/data/2.5/weather?q=tuatapere,nz&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #136: tshikapa, cd
# http://api.openweathermap.org/data/2.5/weather?q=tshikapa,cd&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #137: biograd na moru, hr
# http://api.openweathermap.org/data/2.5/weather?q=biograd na moru,hr&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #138: barrow, us
# http://api.openweathermap.org/data/2.5/weather?q=barrow,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #139: longyearbyen, sj
# http://api.openweathermap.org/data/2.5/weather?q=longyearbyen,sj&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #140: erenhot, cn
# http://api.openweathermap.org/data/2.5/weather?q=erenhot,cn&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #141: loreto, mx
# http://api.openweathermap.org/data/2.5/weather?q=loreto,mx&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #142: belushya guba, ru
# http://api.openweathermap.org/data/2.5/weather?q=belushya guba,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #143: hermanus, za
# http://api.openweathermap.org/data/2.5/weather?q=hermanus,za&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #144: san pedro, ar
# http://api.openweathermap.org/data/2.5/weather?q=san pedro,ar&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #145: lolua, tv
# http://api.openweathermap.org/data/2.5/weather?q=lolua,tv&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #146: grand centre, ca
# http://api.openweathermap.org/data/2.5/weather?q=grand centre,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #147: muroto, jp
# http://api.openweathermap.org/data/2.5/weather?q=muroto,jp&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #148: cariamanga, ec
# http://api.openweathermap.org/data/2.5/weather?q=cariamanga,ec&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #149: grand river south east, mu
# http://api.openweathermap.org/data/2.5/weather?q=grand river south east,mu&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #150: araouane, ml
# http://api.openweathermap.org/data/2.5/weather?q=araouane,ml&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #151: ngukurr, au
# http://api.openweathermap.org/data/2.5/weather?q=ngukurr,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #152: arroyo, us
# http://api.openweathermap.org/data/2.5/weather?q=arroyo,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #153: los llanos de aridane, es
# http://api.openweathermap.org/data/2.5/weather?q=los llanos de aridane,es&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #154: maldonado, uy
# http://api.openweathermap.org/data/2.5/weather?q=maldonado,uy&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #155: mentok, id
# http://api.openweathermap.org/data/2.5/weather?q=mentok,id&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #156: alofi, nu
# http://api.openweathermap.org/data/2.5/weather?q=alofi,nu&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #157: kapaa, us
# http://api.openweathermap.org/data/2.5/weather?q=kapaa,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #158: saint george, bm
# http://api.openweathermap.org/data/2.5/weather?q=saint george,bm&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #159: susehri, tr
# http://api.openweathermap.org/data/2.5/weather?q=susehri,tr&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #160: ayan, ru
# http://api.openweathermap.org/data/2.5/weather?q=ayan,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #161: ponta do sol, pt
# http://api.openweathermap.org/data/2.5/weather?q=ponta do sol,pt&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #162: guerrero negro, mx
# http://api.openweathermap.org/data/2.5/weather?q=guerrero negro,mx&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #163: trelew, ar
# http://api.openweathermap.org/data/2.5/weather?q=trelew,ar&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #164: sitka, us
# http://api.openweathermap.org/data/2.5/weather?q=sitka,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #165: bathsheba, bb
# http://api.openweathermap.org/data/2.5/weather?q=bathsheba,bb&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #166: kodiak, us
# http://api.openweathermap.org/data/2.5/weather?q=kodiak,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #167: lavrentiya, ru
# http://api.openweathermap.org/data/2.5/weather?q=lavrentiya,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #168: sinamar, ph
# http://api.openweathermap.org/data/2.5/weather?q=sinamar,ph&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #169: jamestown, sh
# http://api.openweathermap.org/data/2.5/weather?q=jamestown,sh&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #170: burica, pa
# http://api.openweathermap.org/data/2.5/weather?q=burica,pa&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #171: taksimo, ru
# http://api.openweathermap.org/data/2.5/weather?q=taksimo,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #172: kingman, us
# http://api.openweathermap.org/data/2.5/weather?q=kingman,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #173: te anau, nz
# http://api.openweathermap.org/data/2.5/weather?q=te anau,nz&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #174: gualaquiza, ec
# http://api.openweathermap.org/data/2.5/weather?q=gualaquiza,ec&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #175: espanola, ca
# http://api.openweathermap.org/data/2.5/weather?q=espanola,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #176: aklavik, ca
# http://api.openweathermap.org/data/2.5/weather?q=aklavik,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #177: yar-sale, ru
# http://api.openweathermap.org/data/2.5/weather?q=yar-sale,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #178: rawannawi, ki
# http://api.openweathermap.org/data/2.5/weather?q=rawannawi,ki&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #179: villa carlos paz, ar
# http://api.openweathermap.org/data/2.5/weather?q=villa carlos paz,ar&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #180: ancud, cl
# http://api.openweathermap.org/data/2.5/weather?q=ancud,cl&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #181: tasiilaq, gl
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq,gl&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #182: loralai, pk
# http://api.openweathermap.org/data/2.5/weather?q=loralai,pk&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #183: kangaatsiaq, gl
# http://api.openweathermap.org/data/2.5/weather?q=kangaatsiaq,gl&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #184: ampanihy, mg
# http://api.openweathermap.org/data/2.5/weather?q=ampanihy,mg&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #185: victoria, sc
# http://api.openweathermap.org/data/2.5/weather?q=victoria,sc&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #186: batemans bay, au
# http://api.openweathermap.org/data/2.5/weather?q=batemans bay,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #187: souillac, mu
# http://api.openweathermap.org/data/2.5/weather?q=souillac,mu&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #188: nisia floresta, br
# http://api.openweathermap.org/data/2.5/weather?q=nisia floresta,br&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #189: elliot lake, ca
# http://api.openweathermap.org/data/2.5/weather?q=elliot lake,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #190: oytal, kz
# http://api.openweathermap.org/data/2.5/weather?q=oytal,kz&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #191: talnakh, ru
# http://api.openweathermap.org/data/2.5/weather?q=talnakh,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #192: morondava, mg
# http://api.openweathermap.org/data/2.5/weather?q=morondava,mg&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #193: wenzhou, cn
# http://api.openweathermap.org/data/2.5/weather?q=wenzhou,cn&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #194: hambantota, lk
# http://api.openweathermap.org/data/2.5/weather?q=hambantota,lk&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #195: tulsipur, np
# http://api.openweathermap.org/data/2.5/weather?q=tulsipur,np&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #196: mahebourg, mu
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg,mu&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #197: kautokeino, no
# http://api.openweathermap.org/data/2.5/weather?q=kautokeino,no&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #198: klyuchi, ru
# http://api.openweathermap.org/data/2.5/weather?q=klyuchi,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #199: balykshi, kz
# http://api.openweathermap.org/data/2.5/weather?q=balykshi,kz&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #200: hirara, jp
# http://api.openweathermap.org/data/2.5/weather?q=hirara,jp&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #201: ribeira grande, pt
# http://api.openweathermap.org/data/2.5/weather?q=ribeira grande,pt&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #202: comodoro rivadavia, ar
# http://api.openweathermap.org/data/2.5/weather?q=comodoro rivadavia,ar&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #203: esperance, au
# http://api.openweathermap.org/data/2.5/weather?q=esperance,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #204: prince rupert, ca
# http://api.openweathermap.org/data/2.5/weather?q=prince rupert,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #205: kerouane, gn
# http://api.openweathermap.org/data/2.5/weather?q=kerouane,gn&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #206: soe, id
# http://api.openweathermap.org/data/2.5/weather?q=soe,id&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #207: faya, td
# http://api.openweathermap.org/data/2.5/weather?q=faya,td&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #208: chuy, uy
# http://api.openweathermap.org/data/2.5/weather?q=chuy,uy&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #209: jian, cn
# http://api.openweathermap.org/data/2.5/weather?q=jian,cn&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #210: santa rosa, ar
# http://api.openweathermap.org/data/2.5/weather?q=santa rosa,ar&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #211: tilichiki, ru
# http://api.openweathermap.org/data/2.5/weather?q=tilichiki,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #212: kruisfontein, za
# http://api.openweathermap.org/data/2.5/weather?q=kruisfontein,za&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #213: tulun, ru
# http://api.openweathermap.org/data/2.5/weather?q=tulun,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #214: fort nelson, ca
# http://api.openweathermap.org/data/2.5/weather?q=fort nelson,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #215: kavaratti, in
# http://api.openweathermap.org/data/2.5/weather?q=kavaratti,in&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #216: hithadhoo, mv
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo,mv&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #217: georgetown, sh
# http://api.openweathermap.org/data/2.5/weather?q=georgetown,sh&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #218: kharp, ru
# http://api.openweathermap.org/data/2.5/weather?q=kharp,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #219: surin, th
# http://api.openweathermap.org/data/2.5/weather?q=surin,th&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #220: ghanzi, bw
# http://api.openweathermap.org/data/2.5/weather?q=ghanzi,bw&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #221: marystown, ca
# http://api.openweathermap.org/data/2.5/weather?q=marystown,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #222: bud, no
# http://api.openweathermap.org/data/2.5/weather?q=bud,no&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #223: quatre cocos, mu
# http://api.openweathermap.org/data/2.5/weather?q=quatre cocos,mu&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #224: sussex, ca
# http://api.openweathermap.org/data/2.5/weather?q=sussex,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #225: cache creek, ca
# http://api.openweathermap.org/data/2.5/weather?q=cache creek,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #226: cordoba, ar
# http://api.openweathermap.org/data/2.5/weather?q=cordoba,ar&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #227: saquena, pe
# http://api.openweathermap.org/data/2.5/weather?q=saquena,pe&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #228: saint-pierre, pm
# http://api.openweathermap.org/data/2.5/weather?q=saint-pierre,pm&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #229: russell, nz
# http://api.openweathermap.org/data/2.5/weather?q=russell,nz&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #230: quimper, fr
# http://api.openweathermap.org/data/2.5/weather?q=quimper,fr&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #231: coruripe, br
# http://api.openweathermap.org/data/2.5/weather?q=coruripe,br&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #232: sarangani, ph
# http://api.openweathermap.org/data/2.5/weather?q=sarangani,ph&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #233: tarija, bo
# http://api.openweathermap.org/data/2.5/weather?q=tarija,bo&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #234: dillon, us
# http://api.openweathermap.org/data/2.5/weather?q=dillon,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #235: chagda, ru
# http://api.openweathermap.org/data/2.5/weather?q=chagda,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #236: warmbad, na
# http://api.openweathermap.org/data/2.5/weather?q=warmbad,na&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #237: saint anthony, ca
# http://api.openweathermap.org/data/2.5/weather?q=saint anthony,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #238: barentsburg, sj
# http://api.openweathermap.org/data/2.5/weather?q=barentsburg,sj&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #239: praia da vitoria, pt
# http://api.openweathermap.org/data/2.5/weather?q=praia da vitoria,pt&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #240: nyurba, ru
# http://api.openweathermap.org/data/2.5/weather?q=nyurba,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #241: jucas, br
# http://api.openweathermap.org/data/2.5/weather?q=jucas,br&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #242: tiznit, ma
# http://api.openweathermap.org/data/2.5/weather?q=tiznit,ma&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #243: tsumeb, na
# http://api.openweathermap.org/data/2.5/weather?q=tsumeb,na&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #244: saskylakh, ru
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #245: lishan, cn
# http://api.openweathermap.org/data/2.5/weather?q=lishan,cn&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #246: sentyabrskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=sentyabrskiy,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #247: vardo, no
# http://api.openweathermap.org/data/2.5/weather?q=vardo,no&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #248: usinsk, ru
# http://api.openweathermap.org/data/2.5/weather?q=usinsk,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #249: wanaka, nz
# http://api.openweathermap.org/data/2.5/weather?q=wanaka,nz&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #250: karaul, ru
# http://api.openweathermap.org/data/2.5/weather?q=karaul,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #251: hasaki, jp
# http://api.openweathermap.org/data/2.5/weather?q=hasaki,jp&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #252: gidam, in
# http://api.openweathermap.org/data/2.5/weather?q=gidam,in&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #253: pacific grove, us
# http://api.openweathermap.org/data/2.5/weather?q=pacific grove,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #254: ilulissat, gl
# http://api.openweathermap.org/data/2.5/weather?q=ilulissat,gl&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #255: matara, lk
# http://api.openweathermap.org/data/2.5/weather?q=matara,lk&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #256: zemio, cf
# http://api.openweathermap.org/data/2.5/weather?q=zemio,cf&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #257: saleaula, ws
# http://api.openweathermap.org/data/2.5/weather?q=saleaula,ws&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #258: kyra, ru
# http://api.openweathermap.org/data/2.5/weather?q=kyra,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #259: geraldton, au
# http://api.openweathermap.org/data/2.5/weather?q=geraldton,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #260: cap-aux-meules, ca
# http://api.openweathermap.org/data/2.5/weather?q=cap-aux-meules,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #261: kloulklubed, pw
# http://api.openweathermap.org/data/2.5/weather?q=kloulklubed,pw&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #262: dzerzhinskoye, ru
# http://api.openweathermap.org/data/2.5/weather?q=dzerzhinskoye,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #263: jinchang, cn
# http://api.openweathermap.org/data/2.5/weather?q=jinchang,cn&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #264: turukhansk, ru
# http://api.openweathermap.org/data/2.5/weather?q=turukhansk,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #265: fare, pf
# http://api.openweathermap.org/data/2.5/weather?q=fare,pf&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #266: sumbawa, id
# http://api.openweathermap.org/data/2.5/weather?q=sumbawa,id&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #267: louisbourg, ca
# http://api.openweathermap.org/data/2.5/weather?q=louisbourg,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #268: kutum, sd
# http://api.openweathermap.org/data/2.5/weather?q=kutum,sd&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #269: mopti, ml
# http://api.openweathermap.org/data/2.5/weather?q=mopti,ml&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #270: riyaq, lb
# http://api.openweathermap.org/data/2.5/weather?q=riyaq,lb&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #271: kazalinsk, kz
# http://api.openweathermap.org/data/2.5/weather?q=kazalinsk,kz&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #272: taoudenni, ml
# http://api.openweathermap.org/data/2.5/weather?q=taoudenni,ml&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #273: itapetininga, br
# http://api.openweathermap.org/data/2.5/weather?q=itapetininga,br&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #274: tarko-sale, ru
# http://api.openweathermap.org/data/2.5/weather?q=tarko-sale,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #275: arraial do cabo, br
# http://api.openweathermap.org/data/2.5/weather?q=arraial do cabo,br&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #276: sangueya, gn
# http://api.openweathermap.org/data/2.5/weather?q=sangueya,gn&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #277: poum, nc
# http://api.openweathermap.org/data/2.5/weather?q=poum,nc&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #278: inzer, ru
# http://api.openweathermap.org/data/2.5/weather?q=inzer,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #279: areka, et
# http://api.openweathermap.org/data/2.5/weather?q=areka,et&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #280: ponta delgada, pt
# http://api.openweathermap.org/data/2.5/weather?q=ponta delgada,pt&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #281: rock sound, bs
# http://api.openweathermap.org/data/2.5/weather?q=rock sound,bs&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #282: anadyr, ru
# http://api.openweathermap.org/data/2.5/weather?q=anadyr,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #283: plettenberg bay, za
# http://api.openweathermap.org/data/2.5/weather?q=plettenberg bay,za&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #284: murgab, tm
# http://api.openweathermap.org/data/2.5/weather?q=murgab,tm&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #285: bandarbeyla, so
# http://api.openweathermap.org/data/2.5/weather?q=bandarbeyla,so&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #286: independence, us
# http://api.openweathermap.org/data/2.5/weather?q=independence,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #287: vangaindrano, mg
# http://api.openweathermap.org/data/2.5/weather?q=vangaindrano,mg&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #288: umm lajj, sa
# http://api.openweathermap.org/data/2.5/weather?q=umm lajj,sa&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #289: madaoua, ne
# http://api.openweathermap.org/data/2.5/weather?q=madaoua,ne&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #290: toliary, mg
# http://api.openweathermap.org/data/2.5/weather?q=toliary,mg&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #291: holland, us
# http://api.openweathermap.org/data/2.5/weather?q=holland,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #292: byron bay, au
# http://api.openweathermap.org/data/2.5/weather?q=byron bay,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #293: santa rosa del sur, co
# http://api.openweathermap.org/data/2.5/weather?q=santa rosa del sur,co&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #294: boyolangu, id
# http://api.openweathermap.org/data/2.5/weather?q=boyolangu,id&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #295: walvis bay, na
# http://api.openweathermap.org/data/2.5/weather?q=walvis bay,na&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #296: manbij, sy
# http://api.openweathermap.org/data/2.5/weather?q=manbij,sy&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #297: muisne, ec
# http://api.openweathermap.org/data/2.5/weather?q=muisne,ec&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #298: argelia, co
# http://api.openweathermap.org/data/2.5/weather?q=argelia,co&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #299: khash, ir
# http://api.openweathermap.org/data/2.5/weather?q=khash,ir&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #300: coos bay, us
# http://api.openweathermap.org/data/2.5/weather?q=coos bay,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #301: candawaga, ph
# ...
# http://api.openweathermap.org/data/2.5/weather?q=babenhausen,de&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #667: port-gentil, ga
# http://api.openweathermap.org/data/2.5/weather?q=port-gentil,ga&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #668: roebourne, au
# http://api.openweathermap.org/data/2.5/weather?q=roebourne,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #669: tawkar, sd
# http://api.openweathermap.org/data/2.5/weather?q=tawkar,sd&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #670: flinders, au
# http://api.openweathermap.org/data/2.5/weather?q=flinders,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #671: darab, ir
# http://api.openweathermap.org/data/2.5/weather?q=darab,ir&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #672: kieta, pg
# http://api.openweathermap.org/data/2.5/weather?q=kieta,pg&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #673: klaksvik, fo
# http://api.openweathermap.org/data/2.5/weather?q=klaksvik,fo&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #674: barcelos, br
# http://api.openweathermap.org/data/2.5/weather?q=barcelos,br&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #675: dedovichi, ru
# http://api.openweathermap.org/data/2.5/weather?q=dedovichi,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #676: pierre, us
# http://api.openweathermap.org/data/2.5/weather?q=pierre,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #677: olsztyn, pl
# http://api.openweathermap.org/data/2.5/weather?q=olsztyn,pl&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #678: shubarshi, kz
# http://api.openweathermap.org/data/2.5/weather?q=shubarshi,kz&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #679: bom jardim, br
# http://api.openweathermap.org/data/2.5/weather?q=bom jardim,br&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #680: acarau, br
# http://api.openweathermap.org/data/2.5/weather?q=acarau,br&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #681: asekeyevo, ru
# http://api.openweathermap.org/data/2.5/weather?q=asekeyevo,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #682: nova olimpia, br
# http://api.openweathermap.org/data/2.5/weather?q=nova olimpia,br&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #683: artyk, ru
# http://api.openweathermap.org/data/2.5/weather?q=artyk,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #684: myitkyina, mm
# http://api.openweathermap.org/data/2.5/weather?q=myitkyina,mm&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #685: kyabe, td
# http://api.openweathermap.org/data/2.5/weather?q=kyabe,td&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #686: oudtshoorn, za
# http://api.openweathermap.org/data/2.5/weather?q=oudtshoorn,za&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #687: omaruru, na
# http://api.openweathermap.org/data/2.5/weather?q=omaruru,na&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #688: ha giang, vn
# http://api.openweathermap.org/data/2.5/weather?q=ha giang,vn&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #689: ballina, ie
# http://api.openweathermap.org/data/2.5/weather?q=ballina,ie&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #690: dakar, sn
# http://api.openweathermap.org/data/2.5/weather?q=dakar,sn&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #691: berdyuzhye, ru
# http://api.openweathermap.org/data/2.5/weather?q=berdyuzhye,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #692: ikongo, mg
# http://api.openweathermap.org/data/2.5/weather?q=ikongo,mg&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #693: abilene, us
# http://api.openweathermap.org/data/2.5/weather?q=abilene,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #694: nelson bay, au
# http://api.openweathermap.org/data/2.5/weather?q=nelson bay,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #695: yinchuan, cn
# http://api.openweathermap.org/data/2.5/weather?q=yinchuan,cn&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #696: sur, om
# http://api.openweathermap.org/data/2.5/weather?q=sur,om&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #697: vila franca do campo, pt
# http://api.openweathermap.org/data/2.5/weather?q=vila franca do campo,pt&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #698: puerto del rosario, es
# http://api.openweathermap.org/data/2.5/weather?q=puerto del rosario,es&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #699: tura, ru
# http://api.openweathermap.org/data/2.5/weather?q=tura,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #700: key west, us
# http://api.openweathermap.org/data/2.5/weather?q=key west,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #701: sobolevo, ru
# http://api.openweathermap.org/data/2.5/weather?q=sobolevo,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #702: channel-port aux basques, ca
# http://api.openweathermap.org/data/2.5/weather?q=channel-port aux basques,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #703: maniwaki, ca
# http://api.openweathermap.org/data/2.5/weather?q=maniwaki,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #704: alotau, pg
# http://api.openweathermap.org/data/2.5/weather?q=alotau,pg&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #705: manta, ec
# http://api.openweathermap.org/data/2.5/weather?q=manta,ec&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #706: onverwacht, sr
# http://api.openweathermap.org/data/2.5/weather?q=onverwacht,sr&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #707: auki, sb
# http://api.openweathermap.org/data/2.5/weather?q=auki,sb&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #708: magistralnyy, ru
# http://api.openweathermap.org/data/2.5/weather?q=magistralnyy,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #709: mpika, zm
# http://api.openweathermap.org/data/2.5/weather?q=mpika,zm&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #710: taltal, cl
# http://api.openweathermap.org/data/2.5/weather?q=taltal,cl&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #711: lashio, mm
# http://api.openweathermap.org/data/2.5/weather?q=lashio,mm&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #712: georgetown, us
# http://api.openweathermap.org/data/2.5/weather?q=georgetown,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #713: mangrol, in
# http://api.openweathermap.org/data/2.5/weather?q=mangrol,in&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #714: doka, sd
# http://api.openweathermap.org/data/2.5/weather?q=doka,sd&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #715: karpathos, gr
# http://api.openweathermap.org/data/2.5/weather?q=karpathos,gr&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #716: karratha, au
# http://api.openweathermap.org/data/2.5/weather?q=karratha,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #717: ahuimanu, us
# http://api.openweathermap.org/data/2.5/weather?q=ahuimanu,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #718: san cristobal, ec
# http://api.openweathermap.org/data/2.5/weather?q=san cristobal,ec&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #719: pitimbu, br
# http://api.openweathermap.org/data/2.5/weather?q=pitimbu,br&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #720: tomatlan, mx
# http://api.openweathermap.org/data/2.5/weather?q=tomatlan,mx&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #721: portree, gb
# http://api.openweathermap.org/data/2.5/weather?q=portree,gb&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #722: chauny, fr
# http://api.openweathermap.org/data/2.5/weather?q=chauny,fr&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #723: santa vitoria do palmar, br
# http://api.openweathermap.org/data/2.5/weather?q=santa vitoria do palmar,br&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #724: geraldton, ca
# http://api.openweathermap.org/data/2.5/weather?q=geraldton,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #725: drjanovo, bg
# http://api.openweathermap.org/data/2.5/weather?q=drjanovo,bg&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #726: bonavista, ca
# http://api.openweathermap.org/data/2.5/weather?q=bonavista,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #727: boa vista, br
# http://api.openweathermap.org/data/2.5/weather?q=boa vista,br&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #728: kinablangan, ph
# http://api.openweathermap.org/data/2.5/weather?q=kinablangan,ph&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #729: cartagena, co
# http://api.openweathermap.org/data/2.5/weather?q=cartagena,co&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #730: sept-iles, ca
# http://api.openweathermap.org/data/2.5/weather?q=sept-iles,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #731: port hardy, ca
# http://api.openweathermap.org/data/2.5/weather?q=port hardy,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #732: chiredzi, zw
# http://api.openweathermap.org/data/2.5/weather?q=chiredzi,zw&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #733: vallenar, cl
# http://api.openweathermap.org/data/2.5/weather?q=vallenar,cl&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #734: dicabisagan, ph
# http://api.openweathermap.org/data/2.5/weather?q=dicabisagan,ph&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #735: rundu, na
# http://api.openweathermap.org/data/2.5/weather?q=rundu,na&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #736: hovd, mn
# http://api.openweathermap.org/data/2.5/weather?q=hovd,mn&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #737: acapulco, mx
# http://api.openweathermap.org/data/2.5/weather?q=acapulco,mx&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #738: barbar, sd
# http://api.openweathermap.org/data/2.5/weather?q=barbar,sd&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #739: santa luzia, br
# http://api.openweathermap.org/data/2.5/weather?q=santa luzia,br&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #740: nouadhibou, mr
# http://api.openweathermap.org/data/2.5/weather?q=nouadhibou,mr&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #741: chau doc, vn
# http://api.openweathermap.org/data/2.5/weather?q=chau doc,vn&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #742: ijaki, ki
# http://api.openweathermap.org/data/2.5/weather?q=ijaki,ki&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #743: cetraro, it
# http://api.openweathermap.org/data/2.5/weather?q=cetraro,it&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #744: manokwari, id
# http://api.openweathermap.org/data/2.5/weather?q=manokwari,id&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #745: surt, ly
# http://api.openweathermap.org/data/2.5/weather?q=surt,ly&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #746: krasnoselkup, ru
# http://api.openweathermap.org/data/2.5/weather?q=krasnoselkup,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Error with city data. Skipping
# Now retrieving City #747: surgut, ru
# http://api.openweathermap.org/data/2.5/weather?q=surgut,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #748: knysna, za
# http://api.openweathermap.org/data/2.5/weather?q=knysna,za&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #749: petropavlovsk-kamchatskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=petropavlovsk-kamchatskiy,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #750: namatanai, pg
# http://api.openweathermap.org/data/2.5/weather?q=namatanai,pg&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #751: hervey bay, au
# http://api.openweathermap.org/data/2.5/weather?q=hervey bay,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #752: chinsali, zm
# http://api.openweathermap.org/data/2.5/weather?q=chinsali,zm&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #753: tessalit, ml
# http://api.openweathermap.org/data/2.5/weather?q=tessalit,ml&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #754: sheboygan, us
# http://api.openweathermap.org/data/2.5/weather?q=sheboygan,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #755: merzifon, tr
# http://api.openweathermap.org/data/2.5/weather?q=merzifon,tr&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #756: roald, no
# http://api.openweathermap.org/data/2.5/weather?q=roald,no&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #757: beaumont, us
# http://api.openweathermap.org/data/2.5/weather?q=beaumont,us&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #758: moranbah, au
# http://api.openweathermap.org/data/2.5/weather?q=moranbah,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #759: wajir, ke
# http://api.openweathermap.org/data/2.5/weather?q=wajir,ke&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #760: whitehorse, ca
# http://api.openweathermap.org/data/2.5/weather?q=whitehorse,ca&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #761: novonikolsk, ru
# http://api.openweathermap.org/data/2.5/weather?q=novonikolsk,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #762: ishigaki, jp
# http://api.openweathermap.org/data/2.5/weather?q=ishigaki,jp&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #763: san andres, co
# http://api.openweathermap.org/data/2.5/weather?q=san andres,co&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #764: berlevag, no
# http://api.openweathermap.org/data/2.5/weather?q=berlevag,no&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #765: mount isa, au
# http://api.openweathermap.org/data/2.5/weather?q=mount isa,au&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# Now retrieving City #766: sinegorye, ru
# http://api.openweathermap.org/data/2.5/weather?q=sinegorye,ru&units=imperial&appid=f3dcb25fbddf85b3b397c8fc359b97fe
# ---------------------------------
# Data Retrieval Complete
# ---------------------------------

# %%
# Changing strings to floats
columns = ['Latitude', 'Temperature (F)', 'Humidity (%)', 'Cloudiness (%)', 'Wind Speed (mph)']
for column in columns:
    cities_df[column] = pd.to_numeric(cities_df[column], errors='coerce')
    
# Dropping NaN values
cities_df.dropna(inplace=True)

cities_df.head()
# Out:
#    City Name Country Code  Latitude Longitude  Temperature (F)  Humidity (%)  \
# 0  upernavik           gl     72.79    -56.15            33.74          93.0
# 1     atuona           pf     -9.80   -139.03            81.08          99.0
# 2    iqaluit           ca     63.75    -68.52            39.20          69.0
# 3       gizo           sb     -8.10    156.84            81.62         100.0
# 4     bethel           us     60.79   -161.76            50.00          93.0
#
#    Cloudiness (%)  Wind Speed (mph)
# 0           100.0              5.39
# 1            56.0             14.00
# 2            75.0              3.36
# 3            68.0             18.81
# 4            90.0              3.36

# %%
# Exporting DataFrame
cities_df.to_csv("weather_info.csv")

# %%
#Latitude vs Teperature Plot

# Axes values# Axes  
x_axis = cities_df['Latitude']
y_axis = cities_df['Temperature (F)']

plt.scatter(x_axis, y_axis, c='navy', edgecolors='black')

plt.title("City Latitude vs. Temperature")
plt.xlabel("Latitude")
plt.xlim(-60,90)
plt.ylabel("Temperature (F)")
plt.ylim(-20,125)

plt.savefig("LatitudeVsTemperature.png")
plt.show()

# %%
#Latitude vs Humidity

# Axes values# Axes  
x_axis = cities_df['Latitude']
y_axis = cities_df['Humidity (%)']

plt.scatter(x_axis, y_axis, c='navy', edgecolors='black', alpha=1)

plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.xlim(-60,90)
plt.ylabel("Humidity (%)")
plt.ylim(-20,110)

plt.savefig("LatitudeVsHumidity.png")
plt.show()

# %%
#Latitude vs Cloudiness
# Axes values
x_axis = cities_df['Latitude']
y_axis = cities_df['Cloudiness (%)']

plt.scatter(x_axis, y_axis, c='navy', edgecolors='black', alpha=1)

plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.xlim(-60,90)
plt.ylabel("Cloudiness (%)")
plt.ylim(-20,110)

plt.savefig("LatitudeVsCloudiness.png")
plt.show()

# %%
#Latitude vs Wind Speed
# Axes values
x_axis = cities_df['Latitude']
y_axis = cities_df['Wind Speed (mph)']

plt.scatter(x_axis, y_axis, c='navy', edgecolors='black', alpha=1)

plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.xlim(-60,90)
plt.ylabel("Wind Speed (mph)")
plt.ylim(-5,40)

plt.savefig("LatitudeVsWindSpeed.png")
plt.show()
